# %% [markdown]
# https://towardsdatascience.com/multi-class-text-classification-model-comparison-and-selection-5eb066197568

# %%
import glob
import pandas as pd
import numpy as np
import json

# %%
annotations=glob.glob('data/OPP-115/annotations/*')

# %%
annotations_list=[]
for file in annotations:
    annotations_list.append(pd.read_csv(file, header=None))

# %%
annot=pd.concat(annotations_list, ignore_index=True)

# %%
annot.columns = ['annotation_ID', 'batch_ID', 'annotator_ID', 'policy_ID', 'segment_ID','category_name',
            'attribute_value_pairs','date','policy_URL']

# %%
annot['dict'] = annot.attribute_value_pairs.apply(lambda x: json.loads(x))

# %%
annot.head()
# Out:
#    annotation_ID                                       batch_ID  annotator_ID  \
# 0          13160  test_category_labeling_highlight_fordham_aaaa           121
# 1          13161  test_category_labeling_highlight_fordham_aaaa           121
# 2          13162  test_category_labeling_highlight_fordham_aaaa           121
# 3          13163  test_category_labeling_highlight_fordham_aaaa           121
# 4          13164  test_category_labeling_highlight_fordham_aaaa           121
#
#    policy_ID  segment_ID               category_name  \
# 0       3828           0                       Other
# 1       3828           1  First Party Collection/Use
# 2       3828           1  First Party Collection/Use
# 3       3828           1  First Party Collection/Use
# 4       3828           1  First Party Collection/Use
#
#                                attribute_value_pairs    date  \
# 0  {"Other Type": {"endIndexInSegment": 575, "sta...  5/7/15
# 1  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 2  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 3  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 4  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
#
#                                           policy_URL  \
# 0  http://www.kraftrecipes.com/about/privacynotic...
# 1  http://www.kraftrecipes.com/about/privacynotic...
# 2  http://www.kraftrecipes.com/about/privacynotic...
# 3  http://www.kraftrecipes.com/about/privacynotic...
# 4  http://www.kraftrecipes.com/about/privacynotic...
#
#                                                 dict
# 0  {'Other Type': {'endIndexInSegment': 575, 'sta...
# 1  {'Collection Mode': {'endIndexInSegment': -1, ...
# 2  {'Collection Mode': {'endIndexInSegment': -1, ...
# 3  {'Collection Mode': {'endIndexInSegment': -1, ...
# 4  {'Collection Mode': {'endIndexInSegment': -1, ...

# %%
for x in annot['dict']:
    for key, value in x.items():
        value.pop('endIndexInSegment', None)
        value.pop('startIndexInSegment', None)

# %%
text=[]
category=[]
subcat=[]
label=[]
counter=0
for i,x in enumerate(annot['dict']):
    for key, value in x.items():
        subcat.append(key)
        if value.get('selectedText')==None:
            text.append('noSelectedText')
        else:
            text.append(value.get('selectedText'))  
        category.append(annot['category_name'][i])
        for k, v in value.items():
            if k=='value':
                label.append(v)

# %%
d=list(zip(text, category, subcat, label))

# %%
data=pd.DataFrame(d, columns=['text', 'category', 'subcategory', 'label'])

# %%
data.head()
# Out:
#                                                 text  \
# 0  Effective Date: May 7, 2015 Kraft Site Privacy...
# 1                                     noSelectedText
# 2                                             collec
# 3  register on our website or participate in our ...
# 4       personally-identifiable information, such as
#
#                      category                subcategory  \
# 0                       Other                 Other Type
# 1  First Party Collection/Use            Collection Mode
# 2  First Party Collection/Use               Choice Scope
# 3  First Party Collection/Use         Action First-Party
# 4  First Party Collection/Use  Personal Information Type
#
#                           label
# 0          Introductory/Generic
# 1                  not-selected
# 2                    Collection
# 3            Collect on website
# 4  Generic personal information

# %%
data['cat_sub'] = data['category'] +'-'+ data['subcategory']

# %%
data.groupby('cat_sub').count()
# Out:
#                                                     text  category  \
# cat_sub
# Data Retention-Personal Information Type             370       370
# Data Retention-Retention Period                      370       370
# Data Retention-Retention Purpose                     370       370
# Data Security-Security Measure                      1008      1008
# Do Not Track-Do Not Track policy                      90        90
# First Party Collection/Use-Action First-Party       8935      8935
# First Party Collection/Use-Choice Scope             8935      8935
# First Party Collection/Use-Choice Type              8935      8935
# First Party Collection/Use-Collection Mode          8935      8935
# First Party Collection/Use-Does/Does Not            8935      8935
# First Party Collection/Use-Identifiability          8935      8935
# First Party Collection/Use-Personal Information...  8935      8935
# First Party Collection/Use-Purpose                  8935      8935
# First Party Collection/Use-User Type                8935      8935
# International and Specific Audiences-Audience Type   939       939
# Other-Other Type                                    3548      3548
# Policy Change-Change Type                            548       548
# Policy Change-Notification Type                      548       548
# Policy Change-User Choice                            548       548
# Third Party Sharing/Collection-Action Third Party   5221      5221
# Third Party Sharing/Collection-Choice Scope         5221      5221
# Third Party Sharing/Collection-Choice Type          5221      5221
# Third Party Sharing/Collection-Does/Does Not        5221      5221
# Third Party Sharing/Collection-Identifiability      5221      5221
# Third Party Sharing/Collection-Personal Informa...  5221      5221
# Third Party Sharing/Collection-Purpose              5221      5221
# Third Party Sharing/Collection-Third Party Entity   5221      5221
# Third Party Sharing/Collection-User Type            5221      5221
# User Access, Edit and Deletion-Access Scope          746       746
# User Access, Edit and Deletion-Access Type           746       746
# User Access, Edit and Deletion-User Type             746       746
# User Choice/Control-Choice Scope                    1789      1789
# User Choice/Control-Choice Type                     1789      1789
# User Choice/Control-Personal Information Type       1789      1789
# User Choice/Control-Purpose                         1789      1789
# User Choice/Control-User Type                       1789      1789
#
#                                                     subcategory  label
# cat_sub
# Data Retention-Personal Information Type                    370    370
# Data Retention-Retention Period                             370    370
# Data Retention-Retention Purpose                            370    370
# Data Security-Security Measure                             1008   1008
# Do Not Track-Do Not Track policy                             90     90
# First Party Collection/Use-Action First-Party              8935   8935
# First Party Collection/Use-Choice Scope                    8935   8935
# First Party Collection/Use-Choice Type                     8935   8935
# First Party Collection/Use-Collection Mode                 8935   8935
# First Party Collection/Use-Does/Does Not                   8935   8935
# First Party Collection/Use-Identifiability                 8935   8935
# First Party Collection/Use-Personal Information...         8935   8935
# First Party Collection/Use-Purpose                         8935   8935
# First Party Collection/Use-User Type                       8935   8935
# International and Specific Audiences-Audience Type          939    939
# Other-Other Type                                           3548   3548
# Policy Change-Change Type                                   548    548
# Policy Change-Notification Type                             548    548
# Policy Change-User Choice                                   548    548
# Third Party Sharing/Collection-Action Third Party          5221   5221
# Third Party Sharing/Collection-Choice Scope                5221   5221
# Third Party Sharing/Collection-Choice Type                 5221   5221
# Third Party Sharing/Collection-Does/Does Not               5221   5221
# Third Party Sharing/Collection-Identifiability             5221   5221
# Third Party Sharing/Collection-Personal Informa...         5221   5221
# Third Party Sharing/Collection-Purpose                     5221   5221
# Third Party Sharing/Collection-Third Party Entity          5221   5221
# Third Party Sharing/Collection-User Type                   5221   5221
# User Access, Edit and Deletion-Access Scope                 746    746
# User Access, Edit and Deletion-Access Type                  746    746
# User Access, Edit and Deletion-User Type                    746    746
# User Choice/Control-Choice Scope                           1789   1789
# User Choice/Control-Choice Type                            1789   1789
# User Choice/Control-Personal Information Type              1789   1789
# User Choice/Control-Purpose                                1789   1789
# User Choice/Control-User Type                              1789   1789

# %%
data.groupby(['category','subcategory']).nunique().count()
# Out:
# text           36
# category       36
# subcategory    36
# label          36
# cat_sub        36
# dtype: int64

# %%
data['cat_sub_lab'] = data['category'] +'-'+ data['subcategory'] +'-'+ data['label']

# %%
import string, re
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct
data['text'] = data['text'].apply(lambda x : remove_punct(x.lower()))

data = data[data['text']!='null']
data = data[data['text']!='noselectedtext']
data = data[data['text']!='']
data = data[data['text']!=' ']
data.reset_index(inplace=True, drop=True)
ds = data.drop_duplicates()

# %%
ds.shape
# Out:
# (36717, 6)

# %%
ds.groupby('category').count()
# Out:
#                                        text  subcategory  label  cat_sub  \
# category
# Data Retention                          676          676    676      676
# Data Security                           808          808    808      808
# Do Not Track                             67           67     67       67
# First Party Collection/Use            15346        15346  15346    15346
# International and Specific Audiences    582          582    582      582
# Other                                  2759         2759   2759     2759
# Policy Change                           932          932    932      932
# Third Party Sharing/Collection        10655        10655  10655    10655
# User Access, Edit and Deletion         1094         1094   1094     1094
# User Choice/Control                    3798         3798   3798     3798
#
#                                       cat_sub_lab
# category
# Data Retention                                676
# Data Security                                 808
# Do Not Track                                   67
# First Party Collection/Use                  15346
# International and Specific Audiences          582
# Other                                        2759
# Policy Change                                 932
# Third Party Sharing/Collection              10655
# User Access, Edit and Deletion               1094
# User Choice/Control                          3798

# %%
ds.groupby(['category','subcategory']).count().shape
# Out:
# (36, 4)

# %%
ds.groupby(['category','subcategory','label']).count().shape
# Out:
# (259, 3)

# %%
ds['tokenized'] = ds['text'].apply(lambda x : re.split(' ', x))
# ds['tokenized_text']=res
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from gensim.models import Word2Vec
import logging
 
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# w2v = Word2Vec(ds['tokenized'])
# w2v.save('word2vec.model')

# %%
w2v = Word2Vec.load('word2vec.model')
# Out:
# 2019-09-19 15:58:32,819 : INFO : loading Word2Vec object from word2vec.model
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-09-19 15:58:32,878 : INFO : loading wv recursively from word2vec.model.wv.* with mmap=None
# 2019-09-19 15:58:32,879 : INFO : setting ignored attribute vectors_norm to None
# 2019-09-19 15:58:32,880 : INFO : loading vocabulary recursively from word2vec.model.vocabulary.* with mmap=None
# 2019-09-19 15:58:32,887 : INFO : loading trainables recursively from word2vec.model.trainables.* with mmap=None
# 2019-09-19 15:58:32,888 : INFO : setting ignored attribute cum_table to None
# 2019-09-19 15:58:32,889 : INFO : loaded word2vec.model

# %%
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder()

# %%
ds.reset_index(inplace=True, drop=True)

# %%
word_vectors = w2v.wv

# %%
word2id = {k: v.index for k, v in word_vectors.vocab.items()}

# %%
def add_new_word(new_word, new_vector, new_index, embedding_matrix, word2id):
    embedding_matrix = np.insert(embedding_matrix, [new_index], [new_vector], axis=0)
    
    word2id = {word: (index+1) if index >= new_index else index for word, index in word2id.items()}
    word2id[new_word] = new_index
    return embedding_matrix, word2id

UNK_INDEX = 0
UNK_TOKEN = 'UNK'

embedding_matrix = word_vectors.vectors
unk_vector = embedding_matrix.mean(0)
embedding_matrix, word2id = add_new_word(UNK_TOKEN, unk_vector, UNK_INDEX, embedding_matrix, word2id)

# %%
len(word2id)
# Out:
# 3933

# %%
embedding_matrix.shape
# Out:
# (3933, 100)

# %%
embedding_matrix[0].shape
# Out:
# (100,)

# %%
embedding_matrix = np.insert(embedding_matrix, len(embedding_matrix), [np.zeros((100,))], axis=0)

# %%
len(embedding_matrix)
# Out:
# 3934

# %%
embedding_matrix[3933].shape
# Out:
# (100,)

# %%
def get_int_data(token_text, word2id):
    x = []
    unk_count = 0
    for item in token_text:
        temp=[]
        x.append(temp)
        for word in item:
            if word in word2id:
                temp.append(word2id.get(word))
            else:
                temp.append(UNK_INDEX)
                unk_count += 1
    print('Data created. Percentage of unknown words: %.3f' % (unk_count))
    return np.array(x)

x=get_int_data(ds.tokenized, word2id)
x.shape
# Out:
# Data created. Percentage of unknown words: 7006.000
# (36717,)

# %%
ds['enumerated_text']=x
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#ds['enumerated_text']=ds['enumerated_text'].apply(lambda x: np.array(x))

# %%
target = ds.category

# %%
ds['Do_Not_Track'] = ds['category'].apply(lambda x: 1 if x == 'Do Not Track' else 0)
ds['Other'] = ds['category'].apply(lambda x: 1 if x == 'Other' else 0)
ds['First_Party_Collection_Use'] = ds['category'].apply(lambda x: 1 if x == 'First Party Collection/Use' else 0)
ds['Third_Party_Sharing_Collection'] = ds['category'].apply(lambda x: 1 if x == 'Third Party Sharing/Collection' else 0)
ds['User_Choice_Control'] = ds['category'].apply(lambda x: 1 if x == 'User Choice/Control' else 0)
ds['International_and_Specific_Audiences'] = ds['category'].apply(lambda x: 1 if x == 'International and Specific Audiences' else 0)
ds['Data_Security'] = ds['category'].apply(lambda x: 1 if x == 'Data Security' else 0)
ds['Policy_Change'] = ds['category'].apply(lambda x: 1 if x == 'Policy Change' else 0)
ds['Data_Retention'] = ds['category'].apply(lambda x: 1 if x == 'Data Retention' else 0)
ds['User_Access_Edit_and_Deletion'] = ds['category'].apply(lambda x: 1 if x == 'User Access, Edit and Deletion' else 0)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# sanity check
print(ds['Do_Not_Track'].sum())
print(ds['Other'].sum())
print(ds['First_Party_Collection_Use'].sum())
print(ds['Third_Party_Sharing_Collection'].sum())
print(ds['User_Choice_Control'].sum())
print(ds['International_and_Specific_Audiences'].sum())
print(ds['Data_Security'].sum())
print(ds['Policy_Change'].sum())
print(ds['Data_Retention'].sum())
print(ds['User_Access_Edit_and_Deletion'].sum())
ds.head()
# Out:
# 67
# 2759
# 15346
# 10655
# 3798
# 582
# 808
# 932
# 676
# 1094
#                                                 text  \
# 0  effective date may 7 2015 kraft site privacy n...
# 1                                             collec
# 2  register on our website or participate in our ...
# 3         personallyidentifiable information such as
# 4  if you choose to register on our website or pa...
#
#                      category                subcategory  \
# 0                       Other                 Other Type
# 1  First Party Collection/Use               Choice Scope
# 2  First Party Collection/Use         Action First-Party
# 3  First Party Collection/Use  Personal Information Type
# 4  First Party Collection/Use                Choice Type
#
#                           label  \
# 0          Introductory/Generic
# 1                    Collection
# 2            Collect on website
# 3  Generic personal information
# 4                        Opt-in
#
#                                              cat_sub  \
# 0                                   Other-Other Type
# 1            First Party Collection/Use-Choice Scope
# 2      First Party Collection/Use-Action First-Party
# 3  First Party Collection/Use-Personal Informatio...
# 4             First Party Collection/Use-Choice Type
#
#                                          cat_sub_lab  \
# 0              Other-Other Type-Introductory/Generic
# 1  First Party Collection/Use-Choice Scope-Collec...
# 2  First Party Collection/Use-Action First-Party-...
# 3  First Party Collection/Use-Personal Informatio...
# 4      First Party Collection/Use-Choice Type-Opt-in
#
#                                            tokenized  \
# 0  [effective, date, may, 7, 2015, kraft, site, p...
# 1                                           [collec]
# 2  [register, on, our, website, or, participate, ...
# 3    [personallyidentifiable, information, such, as]
# 4  [if, you, choose, to, register, on, our, websi...
#
#                                      enumerated_text  Do_Not_Track  Other  \
# 0  [553, 244, 11, 2150, 839, 1332, 35, 26, 139, 2...             0      1
# 1                                             [2151]             0      0
# 2     [204, 19, 10, 52, 6, 212, 13, 10, 168, 3, 363]             0      0
# 3                                   [630, 5, 31, 23]             0      0
# 4  [32, 4, 105, 1, 204, 19, 10, 52, 6, 212, 13, 1...             0      0
#
#    First_Party_Collection_Use  Third_Party_Sharing_Collection  \
# 0                           0                               0
# 1                           1                               0
# 2                           1                               0
# 3                           1                               0
# 4                           1                               0
#
#    User_Choice_Control  International_and_Specific_Audiences  Data_Security  \
# 0                    0                                     0              0
# 1                    0                                     0              0
# 2                    0                                     0              0
# 3                    0                                     0              0
# 4                    0                                     0              0
#
#    Policy_Change  Data_Retention  User_Access_Edit_and_Deletion
# 0              0               0                              0
# 1              0               0                              0
# 2              0               0                              0
# 3              0               0                              0
# 4              0               0                              0

# %%
category_df = ds[['enumerated_text','Do_Not_Track','Other','First_Party_Collection_Use','Third_Party_Sharing_Collection',\
                  'User_Choice_Control','International_and_Specific_Audiences','Data_Security','Policy_Change','Data_Retention',\
                 'User_Access_Edit_and_Deletion']]
category_df.head()
# Out:
#                                      enumerated_text  Do_Not_Track  Other  \
# 0  [553, 244, 11, 2150, 839, 1332, 35, 26, 139, 2...             0      1
# 1                                             [2151]             0      0
# 2     [204, 19, 10, 52, 6, 212, 13, 10, 168, 3, 363]             0      0
# 3                                   [630, 5, 31, 23]             0      0
# 4  [32, 4, 105, 1, 204, 19, 10, 52, 6, 212, 13, 1...             0      0
#
#    First_Party_Collection_Use  Third_Party_Sharing_Collection  \
# 0                           0                               0
# 1                           1                               0
# 2                           1                               0
# 3                           1                               0
# 4                           1                               0
#
#    User_Choice_Control  International_and_Specific_Audiences  Data_Security  \
# 0                    0                                     0              0
# 1                    0                                     0              0
# 2                    0                                     0              0
# 3                    0                                     0              0
# 4                    0                                     0              0
#
#    Policy_Change  Data_Retention  User_Access_Edit_and_Deletion
# 0              0               0                              0
# 1              0               0                              0
# 2              0               0                              0
# 3              0               0                              0
# 4              0               0                              0

# %%
from keras.preprocessing.sequence import pad_sequences
max_length = max(category_df.enumerated_text.apply(lambda x: len(x)))
padded_docs = pad_sequences(category_df.enumerated_text, maxlen=max_length, padding='post', value=(len(embedding_matrix)-1))
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Embedding, Activation, Flatten, Dropout

# %%
from keras import regularizers

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Do_Not_Track, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 30.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.05)))
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=5, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('do_not_track.h5')

from sklearn.metrics import confusion_matrix, f1_score, recall_score
print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/5
# 25701/25701 [==============================] - 38s 1ms/step - loss: 1.9654 - acc: 0.9942 - val_loss: 0.3632 - val_acc: 0.9991
# Epoch 2/5
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.2537 - acc: 0.9969 - val_loss: 0.4980 - val_acc: 0.9977
# Epoch 3/5
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.2497 - acc: 0.9972 - val_loss: 0.1675 - val_acc: 0.9977
# Epoch 4/5
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.1502 - acc: 0.9979 - val_loss: 0.1176 - val_acc: 0.9960
# Epoch 5/5
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.1687 - acc: 0.9981 - val_loss: 0.0885 - val_acc: 0.9992
# [[25645     8]
#  [    0    48]]
# 0.923076923076923
# 1.0
# [[10993     4]
#  [    5    14]]
# 0.7567567567567567
# 0.7368421052631579

# %%
from keras import regularizers

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Do_Not_Track, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 300.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
# model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=5, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('do_not_track1.h5')

from sklearn.metrics import confusion_matrix, f1_score, recall_score
print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/5
# 25701/25701 [==============================] - 32s 1ms/step - loss: 1.0135 - acc: 0.9354 - val_loss: 0.0422 - val_acc: 0.9908
# Epoch 2/5
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.4556 - acc: 0.9918 - val_loss: 0.0563 - val_acc: 0.9832
# Epoch 3/5
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.3755 - acc: 0.9961 - val_loss: 0.0157 - val_acc: 0.9970
# Epoch 4/5
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.3472 - acc: 0.9973 - val_loss: 0.0079 - val_acc: 0.9981
# Epoch 5/5
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.3312 - acc: 0.9965 - val_loss: 0.0145 - val_acc: 0.9966
# [[25600    53]
#  [    0    48]]
# 0.6442953020134228
# 1.0
# [[10962    35]
#  [    2    17]]
# 0.4788732394366197
# 0.8947368421052632

# %%
# Other Model
x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Other, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 10.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('other.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# 2019-09-19 16:03:28,769 : WARNING : From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 1.2773 - acc: 0.8166 - val_loss: 0.7469 - val_acc: 0.8270
# Epoch 2/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.9445 - acc: 0.8552 - val_loss: 0.7168 - val_acc: 0.8155
# Epoch 3/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.8930 - acc: 0.8759 - val_loss: 0.6479 - val_acc: 0.8763
# Epoch 4/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.8171 - acc: 0.8893 - val_loss: 0.6865 - val_acc: 0.8577
# Epoch 5/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.7969 - acc: 0.8956 - val_loss: 0.6785 - val_acc: 0.8803
# Epoch 6/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.7994 - acc: 0.9056 - val_loss: 0.7911 - val_acc: 0.8762
# Epoch 7/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.7663 - acc: 0.9118 - val_loss: 0.7169 - val_acc: 0.8706
# Epoch 8/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.7910 - acc: 0.9176 - val_loss: 0.6517 - val_acc: 0.9054
# Epoch 9/10
# 25701/25701 [==============================] - 31s 1ms/step - loss: 0.7200 - acc: 0.9226 - val_loss: 0.6390 - val_acc: 0.9059
# Epoch 10/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 0.7210 - acc: 0.9272 - val_loss: 0.6432 - val_acc: 0.9001
# [[22175  1566]
#  [   39  1921]]
# 0.7053423903065908
# 0.9801020408163266
# [[9298  919]
#  [ 182  617]]
# 0.5284796573875803
# 0.772215269086358

# %%
#  First Party Collection/Use Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.First_Party_Collection_Use, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 10.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('first_party_collection_use.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 31s 1ms/step - loss: 3.6929 - acc: 0.4819 - val_loss: 1.2248 - val_acc: 0.4674
# Epoch 2/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 1.7509 - acc: 0.4985 - val_loss: 1.0588 - val_acc: 0.5737
# Epoch 3/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.6489 - acc: 0.5372 - val_loss: 0.9593 - val_acc: 0.6212
# Epoch 4/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 1.5785 - acc: 0.5642 - val_loss: 1.0767 - val_acc: 0.5790
# Epoch 5/10
# 25701/25701 [==============================] - 27s 1ms/step - loss: 1.5384 - acc: 0.5864 - val_loss: 1.0062 - val_acc: 0.6373
# Epoch 6/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.5190 - acc: 0.6104 - val_loss: 1.2255 - val_acc: 0.5782
# Epoch 7/10
# 25701/25701 [==============================] - 32s 1ms/step - loss: 1.4510 - acc: 0.6297 - val_loss: 1.2226 - val_acc: 0.5969
# Epoch 8/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.4352 - acc: 0.6462 - val_loss: 1.0724 - val_acc: 0.6394
# Epoch 9/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.4413 - acc: 0.6608 - val_loss: 0.9801 - val_acc: 0.6763
# Epoch 10/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 1.3636 - acc: 0.6765 - val_loss: 1.0711 - val_acc: 0.6569
# [[ 7028  7949]
#  [  107 10617]]
# 0.7249573233185387
# 0.9900223797090638
# [[2771 3623]
#  [ 157 4465]]
# 0.7025963808025176
# 0.9660320207702293

# %%
#  Data Retention Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Data_Retention, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 40.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('data_retention.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 1.8084 - acc: 0.7688 - val_loss: 0.9565 - val_acc: 0.8958
# Epoch 2/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 1.5085 - acc: 0.8064 - val_loss: 0.9818 - val_acc: 0.8018
# Epoch 3/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.3653 - acc: 0.8276 - val_loss: 1.0736 - val_acc: 0.8680
# Epoch 4/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.2925 - acc: 0.8541 - val_loss: 0.8046 - val_acc: 0.8646
# Epoch 5/10
# 25701/25701 [==============================] - 35s 1ms/step - loss: 1.2190 - acc: 0.8600 - val_loss: 1.3268 - val_acc: 0.8194
# Epoch 6/10
# 25701/25701 [==============================] - 37s 1ms/step - loss: 1.1946 - acc: 0.8692 - val_loss: 1.1704 - val_acc: 0.8983
# Epoch 7/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.2580 - acc: 0.8863 - val_loss: 0.7950 - val_acc: 0.8453
# Epoch 8/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.0529 - acc: 0.8880 - val_loss: 0.7976 - val_acc: 0.8483
# Epoch 9/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.0656 - acc: 0.8957 - val_loss: 0.7526 - val_acc: 0.8803
# Epoch 10/10
# 25701/25701 [==============================] - 39s 2ms/step - loss: 0.9536 - acc: 0.8962 - val_loss: 0.9100 - val_acc: 0.8512
# [[21861  3356]
#  [    7   477]]
# 0.22098679638637944
# 0.9855371900826446
# [[9243 1581]
#  [  58  134]]
# 0.140534871525957
# 0.6979166666666666

# %%
#  Data Security Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Data_Security, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 40.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='tanh', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('data_security.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 38s 1ms/step - loss: 3.3726 - acc: 0.8531 - val_loss: 1.2980 - val_acc: 0.8066
# Epoch 2/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.1784 - acc: 0.9059 - val_loss: 0.7729 - val_acc: 0.9393
# Epoch 3/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 1.0201 - acc: 0.9259 - val_loss: 0.9635 - val_acc: 0.9192
# Epoch 4/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 0.8670 - acc: 0.9491 - val_loss: 0.7715 - val_acc: 0.8956
# Epoch 5/10
# 25701/25701 [==============================] - 35s 1ms/step - loss: 0.7858 - acc: 0.9544 - val_loss: 0.9829 - val_acc: 0.9551
# Epoch 6/10
# 25701/25701 [==============================] - 38s 1ms/step - loss: 0.7754 - acc: 0.9656 - val_loss: 0.5777 - val_acc: 0.9450
# Epoch 7/10
# 25701/25701 [==============================] - 38s 1ms/step - loss: 0.5883 - acc: 0.9699 - val_loss: 0.5009 - val_acc: 0.9463
# Epoch 8/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.7755 - acc: 0.9722 - val_loss: 0.5196 - val_acc: 0.9736
# Epoch 9/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.5704 - acc: 0.9725 - val_loss: 0.4281 - val_acc: 0.9719
# Epoch 10/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.5418 - acc: 0.9765 - val_loss: 0.6483 - val_acc: 0.9551
# [[24307   843]
#  [    4   547]]
# 0.5636269963936115
# 0.9927404718693285
# [[10304   455]
#  [   40   217]]
# 0.46716899892357383
# 0.8443579766536965

# %%
#  International and Specific Audiences Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.International_and_Specific_Audiences, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 50.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('internation_specific_audiences.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.7937 - acc: 0.9025 - val_loss: 1.1867 - val_acc: 0.9304
# Epoch 2/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.3498 - acc: 0.9265 - val_loss: 1.5433 - val_acc: 0.8526
# Epoch 3/10
# 25701/25701 [==============================] - 32s 1ms/step - loss: 1.3274 - acc: 0.9388 - val_loss: 1.2399 - val_acc: 0.8749
# Epoch 4/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 1.4611 - acc: 0.9468 - val_loss: 0.7992 - val_acc: 0.9736
# Epoch 5/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.9489 - acc: 0.9615 - val_loss: 0.8565 - val_acc: 0.9548
# Epoch 6/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 1.0519 - acc: 0.9637 - val_loss: 0.7693 - val_acc: 0.9484
# Epoch 7/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.9801 - acc: 0.9624 - val_loss: 0.9056 - val_acc: 0.9729
# Epoch 8/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 1.5439 - acc: 0.9703 - val_loss: 0.8080 - val_acc: 0.9787
# Epoch 9/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.5864 - acc: 0.9767 - val_loss: 0.6119 - val_acc: 0.9499
# Epoch 10/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.9311 - acc: 0.9668 - val_loss: 0.9106 - val_acc: 0.9662
# [[24681   625]
#  [    2   393]]
# 0.5562632696390658
# 0.9949367088607595
# [[10485   344]
#  [   28   159]]
# 0.46086956521739125
# 0.8502673796791443

# %%
#  International and Specific Audiences Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.International_and_Specific_Audiences, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 45.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('internation_specific_audiences1.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 49s 2ms/step - loss: 1.7893 - acc: 0.9034 - val_loss: 1.3693 - val_acc: 0.8689
# Epoch 2/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.4448 - acc: 0.9272 - val_loss: 0.8832 - val_acc: 0.9547
# Epoch 3/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.3243 - acc: 0.9404 - val_loss: 0.8640 - val_acc: 0.9567
# Epoch 4/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.0815 - acc: 0.9603 - val_loss: 0.7227 - val_acc: 0.9525
# Epoch 5/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.0090 - acc: 0.9520 - val_loss: 1.1302 - val_acc: 0.9671
# Epoch 6/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.2497 - acc: 0.9614 - val_loss: 0.7594 - val_acc: 0.9732
# Epoch 7/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 0.9044 - acc: 0.9653 - val_loss: 1.0113 - val_acc: 0.9611
# Epoch 8/10
# 25701/25701 [==============================] - 35s 1ms/step - loss: 0.8817 - acc: 0.9729 - val_loss: 0.6635 - val_acc: 0.9614
# Epoch 9/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 1.2442 - acc: 0.9704 - val_loss: 1.5360 - val_acc: 0.9397
# Epoch 10/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 0.7682 - acc: 0.9788 - val_loss: 0.4113 - val_acc: 0.9791
# [[24949   357]
#  [    5   390]]
# 0.6830122591943957
# 0.9873417721518988
# [[10638   191]
#  [   39   148]]
# 0.5627376425855514
# 0.7914438502673797

# %%
#  Policy Change Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Policy_Change, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 25.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='tanh', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('policy_change.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 2.0160 - acc: 0.9315 - val_loss: 0.4001 - val_acc: 0.9462
# Epoch 2/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.3083 - acc: 0.9651 - val_loss: 0.1731 - val_acc: 0.9563
# Epoch 3/10
# 25701/25701 [==============================] - 25s 977us/step - loss: 0.1693 - acc: 0.9746 - val_loss: 0.0952 - val_acc: 0.9769
# Epoch 4/10
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.1152 - acc: 0.9839 - val_loss: 0.1158 - val_acc: 0.9681
# Epoch 5/10
# 25701/25701 [==============================] - 26s 1ms/step - loss: 0.0995 - acc: 0.9859 - val_loss: 0.1448 - val_acc: 0.9596
# Epoch 6/10
# 25701/25701 [==============================] - 37s 1ms/step - loss: 0.0945 - acc: 0.9870 - val_loss: 0.0735 - val_acc: 0.9858
# Epoch 7/10
# 25701/25701 [==============================] - 40s 2ms/step - loss: 0.0706 - acc: 0.9908 - val_loss: 0.0719 - val_acc: 0.9825
# Epoch 8/10
# 25701/25701 [==============================] - 40s 2ms/step - loss: 0.0653 - acc: 0.9902 - val_loss: 0.0784 - val_acc: 0.9832
# Epoch 9/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 0.0651 - acc: 0.9915 - val_loss: 0.0759 - val_acc: 0.9824
# Epoch 10/10
# 25701/25701 [==============================] - 37s 1ms/step - loss: 0.0527 - acc: 0.9925 - val_loss: 0.0726 - val_acc: 0.9847
# [[24920   133]
#  [    2   646]]
# 0.9053959355290819
# 0.9969135802469136
# [[10633    99]
#  [   69   215]]
# 0.7190635451505016
# 0.7570422535211268

# %%
#  Policy Change Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Policy_Change, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 40.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='tanh', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('policy_change1.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 44s 2ms/step - loss: 2.2501 - acc: 0.8980 - val_loss: 0.4916 - val_acc: 0.9321
# Epoch 2/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 0.4059 - acc: 0.9532 - val_loss: 0.1625 - val_acc: 0.9713
# Epoch 3/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 0.2035 - acc: 0.9707 - val_loss: 0.1298 - val_acc: 0.9723
# Epoch 4/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.1471 - acc: 0.9780 - val_loss: 0.1375 - val_acc: 0.9650
# Epoch 5/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.1226 - acc: 0.9825 - val_loss: 0.1159 - val_acc: 0.9713
# Epoch 6/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.1011 - acc: 0.9861 - val_loss: 0.0980 - val_acc: 0.9806
# Epoch 7/10
# 25701/25701 [==============================] - 36s 1ms/step - loss: 0.0844 - acc: 0.9894 - val_loss: 0.1200 - val_acc: 0.9690
# Epoch 8/10
# 25701/25701 [==============================] - 32s 1ms/step - loss: 0.0761 - acc: 0.9890 - val_loss: 0.0921 - val_acc: 0.9773
# Epoch 9/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.0788 - acc: 0.9907 - val_loss: 0.0899 - val_acc: 0.9791
# Epoch 10/10
# 25701/25701 [==============================] - 31s 1ms/step - loss: 0.0601 - acc: 0.9915 - val_loss: 0.0813 - val_acc: 0.9831
# [[24904   149]
#  [    0   648]]
# 0.896885813148789
# 1.0
# [[10608   124]
#  [   62   222]]
# 0.7047619047619047
# 0.7816901408450704

# %%
#  Third Party Sharing/Collection Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Third_Party_Sharing_Collection, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 20}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('third_party_sharing_collection.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 35s 1ms/step - loss: 1.9975 - acc: 0.3345 - val_loss: 1.0548 - val_acc: 0.3955
# Epoch 2/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 1.6575 - acc: 0.4260 - val_loss: 1.1570 - val_acc: 0.4537
# Epoch 3/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 1.4334 - acc: 0.5262 - val_loss: 1.0957 - val_acc: 0.5034
# Epoch 4/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 1.2461 - acc: 0.6109 - val_loss: 1.0722 - val_acc: 0.5453
# Epoch 5/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 1.0972 - acc: 0.6746 - val_loss: 0.9665 - val_acc: 0.6125
# Epoch 6/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.9830 - acc: 0.7211 - val_loss: 0.9718 - val_acc: 0.6350
# Epoch 7/10
# 25701/25701 [==============================] - 28s 1ms/step - loss: 0.8794 - acc: 0.7559 - val_loss: 0.9266 - val_acc: 0.6572
# Epoch 8/10
# 25701/25701 [==============================] - 26s 1ms/step - loss: 0.8159 - acc: 0.7836 - val_loss: 0.9023 - val_acc: 0.6912
# Epoch 9/10
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.7474 - acc: 0.8043 - val_loss: 0.9428 - val_acc: 0.6764
# Epoch 10/10
# 25701/25701 [==============================] - 27s 1ms/step - loss: 0.7210 - acc: 0.8112 - val_loss: 0.9515 - val_acc: 0.7101
# [[13936  4302]
#  [    6  7457]]
# 0.7758818021017584
# 0.9991960337665818
# [[5222 2602]
#  [ 592 2600]]
# 0.619490111984751
# 0.8145363408521303

# %%
#  User Access, Edit and Deletion Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.User_Access_Edit_and_Deletion, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 20}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('user_access_edit_deletion.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 2.8496 - acc: 0.8766 - val_loss: 0.9262 - val_acc: 0.8874
# Epoch 2/10
# 25701/25701 [==============================] - 33s 1ms/step - loss: 1.0224 - acc: 0.8888 - val_loss: 0.8040 - val_acc: 0.8848
# Epoch 3/10
# 25701/25701 [==============================] - 35s 1ms/step - loss: 0.8249 - acc: 0.9066 - val_loss: 0.5465 - val_acc: 0.9021
# Epoch 4/10
# 25701/25701 [==============================] - 40s 2ms/step - loss: 0.6986 - acc: 0.9205 - val_loss: 0.5701 - val_acc: 0.8956
# Epoch 5/10
# 25701/25701 [==============================] - 46s 2ms/step - loss: 0.6119 - acc: 0.9272 - val_loss: 0.5911 - val_acc: 0.9040
# Epoch 6/10
# 25701/25701 [==============================] - 50s 2ms/step - loss: 0.5891 - acc: 0.9279 - val_loss: 0.3745 - val_acc: 0.9437
# Epoch 7/10
# 25701/25701 [==============================] - 63s 2ms/step - loss: 0.5257 - acc: 0.9333 - val_loss: 0.4320 - val_acc: 0.9139
# Epoch 8/10
# 25701/25701 [==============================] - 50s 2ms/step - loss: 0.4995 - acc: 0.9352 - val_loss: 0.3726 - val_acc: 0.9276
# Epoch 9/10
# 25701/25701 [==============================] - 56s 2ms/step - loss: 0.4688 - acc: 0.9419 - val_loss: 0.4965 - val_acc: 0.9245
# Epoch 10/10
# 25701/25701 [==============================] - 51s 2ms/step - loss: 0.4472 - acc: 0.9437 - val_loss: 0.4716 - val_acc: 0.8956
# [[22730  2234]
#  [    6   731]]
# 0.3949216639654241
# 0.9918588873812755
# [[9561 1098]
#  [  52  305]]
# 0.3465909090909091
# 0.8543417366946778

# %%
#  User Access, Edit and Deletion Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.User_Access_Edit_and_Deletion, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 15.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('user_access_edit_deletion1.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 34s 1ms/step - loss: 2.6143 - acc: 0.9125 - val_loss: 0.6677 - val_acc: 0.9326
# Epoch 2/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.8416 - acc: 0.9218 - val_loss: 0.4468 - val_acc: 0.9414
# Epoch 3/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.7319 - acc: 0.9248 - val_loss: 0.4381 - val_acc: 0.9237
# Epoch 4/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.6175 - acc: 0.9316 - val_loss: 0.3657 - val_acc: 0.9594
# Epoch 5/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.5293 - acc: 0.9367 - val_loss: 0.3347 - val_acc: 0.9486
# Epoch 6/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.5315 - acc: 0.9377 - val_loss: 0.4494 - val_acc: 0.9202
# Epoch 7/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.4518 - acc: 0.9442 - val_loss: 0.3636 - val_acc: 0.9175
# Epoch 8/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.4233 - acc: 0.9480 - val_loss: 0.3341 - val_acc: 0.9211
# Epoch 9/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.4390 - acc: 0.9488 - val_loss: 0.3840 - val_acc: 0.9266
# Epoch 10/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.3602 - acc: 0.9535 - val_loss: 0.2910 - val_acc: 0.9430
# [[23907  1057]
#  [   41   696]]
# 0.5590361445783133
# 0.9443690637720489
# [[10118   541]
#  [   87   270]]
# 0.4623287671232877
# 0.7563025210084033

# %%
#  User Choice/Control Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.User_Choice_Control, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 40.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('user_choice_control.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 32s 1ms/step - loss: 1.9909 - acc: 0.2466 - val_loss: 1.0171 - val_acc: 0.4217
# Epoch 2/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 1.5612 - acc: 0.4980 - val_loss: 0.9464 - val_acc: 0.5221
# Epoch 3/10
# 25701/25701 [==============================] - 31s 1ms/step - loss: 1.2496 - acc: 0.6228 - val_loss: 0.8856 - val_acc: 0.5538
# Epoch 4/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 1.0372 - acc: 0.7032 - val_loss: 0.7449 - val_acc: 0.6515
# Epoch 5/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.8470 - acc: 0.7639 - val_loss: 0.7209 - val_acc: 0.7065
# Epoch 6/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.7314 - acc: 0.8031 - val_loss: 0.6742 - val_acc: 0.7436
# Epoch 7/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 0.6365 - acc: 0.8286 - val_loss: 0.6838 - val_acc: 0.7513
# Epoch 8/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.5564 - acc: 0.8545 - val_loss: 0.5418 - val_acc: 0.8123
# Epoch 9/10
# 25701/25701 [==============================] - 30s 1ms/step - loss: 0.5160 - acc: 0.8673 - val_loss: 0.5179 - val_acc: 0.8312
# Epoch 10/10
# 25701/25701 [==============================] - 39s 2ms/step - loss: 0.4472 - acc: 0.8834 - val_loss: 0.6245 - val_acc: 0.8130
# [[19734  3276]
#  [    2  2689]]
# 0.6213031423290203
# 0.9992567818654775
# [[8154 1755]
#  [ 305  802]]
# 0.43777292576419213
# 0.7244805781391147

# %%
#  User Choice/Control Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.User_Choice_Control, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 70.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

model.save('user_choice_control1.h5')

print(confusion_matrix(y_train,model.predict_classes(x_train)))
print(f1_score(y_train, model.predict_classes(x_train)))
print(recall_score(y_train, model.predict_classes(x_train)))
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
print(recall_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 35s 1ms/step - loss: 3.7869 - acc: 0.1715 - val_loss: 3.0915 - val_acc: 0.1854
# Epoch 2/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 3.1636 - acc: 0.2356 - val_loss: 2.1196 - val_acc: 0.2299
# Epoch 3/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 3.0255 - acc: 0.2976 - val_loss: 2.2537 - val_acc: 0.3096
# Epoch 4/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.8229 - acc: 0.3824 - val_loss: 1.9737 - val_acc: 0.4647
# Epoch 5/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.7911 - acc: 0.4714 - val_loss: 3.1724 - val_acc: 0.4348
# Epoch 6/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.5897 - acc: 0.5288 - val_loss: 2.0585 - val_acc: 0.5304
# Epoch 7/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.4823 - acc: 0.5662 - val_loss: 2.8645 - val_acc: 0.4205
# Epoch 8/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.6046 - acc: 0.5911 - val_loss: 1.9277 - val_acc: 0.6068
# Epoch 9/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.1467 - acc: 0.6450 - val_loss: 1.9479 - val_acc: 0.6009
# Epoch 10/10
# 25701/25701 [==============================] - 29s 1ms/step - loss: 2.8980 - acc: 0.6384 - val_loss: 2.0089 - val_acc: 0.6063
# [[13515  9495]
#  [    6  2685]]
# 0.36110550736332464
# 0.9977703455964325
# [[5685 4224]
#  [ 113  994]]
# 0.3143083003952569
# 0.8979223125564589
