# %% [markdown]
# https://towardsdatascience.com/multi-class-text-classification-model-comparison-and-selection-5eb066197568

# %%
import glob
import pandas as pd
import numpy as np
import json

# %%
annotations=glob.glob('data/OPP-115/annotations/*')

# %%
annotations_list=[]
for file in annotations:
    annotations_list.append(pd.read_csv(file, header=None))

# %%
annot=pd.concat(annotations_list, ignore_index=True)

# %%
annot.columns=['annotation_ID', 'batch_ID', 'annotator_ID', 'policy_ID', 'segment_ID','category_name',
            'attribute_value_pairs','date','policy_URL']

# %%
annot['dict']=annot.attribute_value_pairs.apply(lambda x: json.loads(x))

# %%
annot.head()
# Out:
#    annotation_ID                                       batch_ID  annotator_ID  \
# 0          13160  test_category_labeling_highlight_fordham_aaaa           121
# 1          13161  test_category_labeling_highlight_fordham_aaaa           121
# 2          13162  test_category_labeling_highlight_fordham_aaaa           121
# 3          13163  test_category_labeling_highlight_fordham_aaaa           121
# 4          13164  test_category_labeling_highlight_fordham_aaaa           121
#
#    policy_ID  segment_ID               category_name  \
# 0       3828           0                       Other
# 1       3828           1  First Party Collection/Use
# 2       3828           1  First Party Collection/Use
# 3       3828           1  First Party Collection/Use
# 4       3828           1  First Party Collection/Use
#
#                                attribute_value_pairs    date  \
# 0  {"Other Type": {"endIndexInSegment": 575, "sta...  5/7/15
# 1  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 2  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 3  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 4  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
#
#                                           policy_URL  \
# 0  http://www.kraftrecipes.com/about/privacynotic...
# 1  http://www.kraftrecipes.com/about/privacynotic...
# 2  http://www.kraftrecipes.com/about/privacynotic...
# 3  http://www.kraftrecipes.com/about/privacynotic...
# 4  http://www.kraftrecipes.com/about/privacynotic...
#
#                                                 dict
# 0  {'Other Type': {'endIndexInSegment': 575, 'sta...
# 1  {'Collection Mode': {'endIndexInSegment': -1, ...
# 2  {'Collection Mode': {'endIndexInSegment': -1, ...
# 3  {'Collection Mode': {'endIndexInSegment': -1, ...
# 4  {'Collection Mode': {'endIndexInSegment': -1, ...

# %%
text1=[]
for item in annot['dict']:
    temptext=[]
    text1.append(temptext)
    for key,value in item.items():
        if value.get('selectedText')==None:
            temptext.append(str(value.get('selectedText')))
        else:
            temptext.append(value.get('selectedText'))

# %%
text3=[]
for text in text1:
    text3.append(list(np.unique(text)))

# %%
annot['text']=text3

# %%
annot.head()
# Out:
#    annotation_ID                                       batch_ID  annotator_ID  \
# 0          13160  test_category_labeling_highlight_fordham_aaaa           121
# 1          13161  test_category_labeling_highlight_fordham_aaaa           121
# 2          13162  test_category_labeling_highlight_fordham_aaaa           121
# 3          13163  test_category_labeling_highlight_fordham_aaaa           121
# 4          13164  test_category_labeling_highlight_fordham_aaaa           121
#
#    policy_ID  segment_ID               category_name  \
# 0       3828           0                       Other
# 1       3828           1  First Party Collection/Use
# 2       3828           1  First Party Collection/Use
# 3       3828           1  First Party Collection/Use
# 4       3828           1  First Party Collection/Use
#
#                                attribute_value_pairs    date  \
# 0  {"Other Type": {"endIndexInSegment": 575, "sta...  5/7/15
# 1  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 2  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 3  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 4  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
#
#                                           policy_URL  \
# 0  http://www.kraftrecipes.com/about/privacynotic...
# 1  http://www.kraftrecipes.com/about/privacynotic...
# 2  http://www.kraftrecipes.com/about/privacynotic...
# 3  http://www.kraftrecipes.com/about/privacynotic...
# 4  http://www.kraftrecipes.com/about/privacynotic...
#
#                                                 dict  \
# 0  {'Other Type': {'endIndexInSegment': 575, 'sta...
# 1  {'Collection Mode': {'endIndexInSegment': -1, ...
# 2  {'Collection Mode': {'endIndexInSegment': -1, ...
# 3  {'Collection Mode': {'endIndexInSegment': -1, ...
# 4  {'Collection Mode': {'endIndexInSegment': -1, ...
#
#                                                 text
# 0  [Effective Date: May 7, 2015 Kraft Site Privac...
# 1  [None, We collect, certain additional features...
# 2  [None, Sharing this additional information wit...
# 3  [In addition, we may use the information you p...
# 4  [None, We collect, certain additional features...

# %%
for item in annot.text:
    if 'None' in item:
        item.remove('None')

# %%
annot['plain_text']=annot['text'].apply(lambda x: str(x).strip('[]'))
annot.head()
# Out:
#    annotation_ID                                       batch_ID  annotator_ID  \
# 0          13160  test_category_labeling_highlight_fordham_aaaa           121
# 1          13161  test_category_labeling_highlight_fordham_aaaa           121
# 2          13162  test_category_labeling_highlight_fordham_aaaa           121
# 3          13163  test_category_labeling_highlight_fordham_aaaa           121
# 4          13164  test_category_labeling_highlight_fordham_aaaa           121
#
#    policy_ID  segment_ID               category_name  \
# 0       3828           0                       Other
# 1       3828           1  First Party Collection/Use
# 2       3828           1  First Party Collection/Use
# 3       3828           1  First Party Collection/Use
# 4       3828           1  First Party Collection/Use
#
#                                attribute_value_pairs    date  \
# 0  {"Other Type": {"endIndexInSegment": 575, "sta...  5/7/15
# 1  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 2  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 3  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 4  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
#
#                                           policy_URL  \
# 0  http://www.kraftrecipes.com/about/privacynotic...
# 1  http://www.kraftrecipes.com/about/privacynotic...
# 2  http://www.kraftrecipes.com/about/privacynotic...
# 3  http://www.kraftrecipes.com/about/privacynotic...
# 4  http://www.kraftrecipes.com/about/privacynotic...
#
#                                                 dict  \
# 0  {'Other Type': {'endIndexInSegment': 575, 'sta...
# 1  {'Collection Mode': {'endIndexInSegment': -1, ...
# 2  {'Collection Mode': {'endIndexInSegment': -1, ...
# 3  {'Collection Mode': {'endIndexInSegment': -1, ...
# 4  {'Collection Mode': {'endIndexInSegment': -1, ...
#
#                                                 text  \
# 0  [Effective Date: May 7, 2015 Kraft Site Privac...
# 1  [We collect, certain additional features that ...
# 2  [Sharing this additional information with us a...
# 3  [In addition, we may use the information you p...
# 4  [We collect, certain additional features that ...
#
#                                           plain_text
# 0  'Effective Date: May 7, 2015 Kraft Site Privac...
# 1  'We collect', 'certain additional features tha...
# 2  'Sharing this additional information with us a...
# 3  'In addition, we may use the information you p...
# 4  'We collect', 'certain additional features tha...

# %%
annot['plain_text']=annot['plain_text'].apply(lambda x: x.lower())

# %%
x=annot['plain_text']
y=annot['category_name']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 42)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(x_train, y_train)

# %time
from sklearn.metrics import classification_report, accuracy_score
y_pred = nb.predict(x_test)


print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.01 µs
# accuracy 0.7059922402644058
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                       precision    recall  f1-score   support
#
#                       Data Retention       1.00      0.02      0.04       107
#                        Data Security       0.95      0.55      0.69       291
#                         Do Not Track       0.00      0.00      0.00        30
#           First Party Collection/Use       0.67      0.95      0.79      2677
# International and Specific Audiences       0.93      0.46      0.61       299
#                                Other       0.68      0.62      0.65      1104
#                        Policy Change       1.00      0.31      0.47       146
#       Third Party Sharing/Collection       0.74      0.73      0.73      1557
#       User Access, Edit and Deletion       0.96      0.22      0.35       236
#                  User Choice/Control       0.73      0.32      0.45       512
#
#                             accuracy                           0.71      6959
#                            macro avg       0.77      0.42      0.48      6959
#                         weighted avg       0.73      0.71      0.68      6959

# %%
from sklearn.linear_model import SGDClassifier

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
sgd.fit(x_train, y_train)

# %time

y_pred = sgd.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.25 µs
# accuracy 0.7677827274033625
#                                       precision    recall  f1-score   support
#
#                       Data Retention       0.87      0.25      0.39       107
#                        Data Security       0.88      0.71      0.79       291
#                         Do Not Track       0.97      0.97      0.97        30
#           First Party Collection/Use       0.75      0.92      0.82      2677
# International and Specific Audiences       0.84      0.78      0.81       299
#                                Other       0.78      0.63      0.70      1104
#                        Policy Change       0.88      0.65      0.75       146
#       Third Party Sharing/Collection       0.77      0.79      0.78      1557
#       User Access, Edit and Deletion       0.86      0.61      0.71       236
#                  User Choice/Control       0.68      0.42      0.52       512
#
#                             accuracy                           0.77      6959
#                            macro avg       0.83      0.67      0.72      6959
#                         weighted avg       0.77      0.77      0.76      6959

# %%
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=-1, C=1e5)),
               ])
logreg.fit(x_train, y_train)

# %time

y_pred = logreg.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 4.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.2 µs
# accuracy 0.7985342721655411
#                                       precision    recall  f1-score   support
#
#                       Data Retention       0.63      0.67      0.65       107
#                        Data Security       0.78      0.77      0.77       291
#                         Do Not Track       0.96      0.87      0.91        30
#           First Party Collection/Use       0.86      0.86      0.86      2677
# International and Specific Audiences       0.75      0.83      0.79       299
#                                Other       0.75      0.73      0.74      1104
#                        Policy Change       0.82      0.73      0.77       146
#       Third Party Sharing/Collection       0.83      0.81      0.82      1557
#       User Access, Edit and Deletion       0.73      0.77      0.75       236
#                  User Choice/Control       0.58      0.62      0.60       512
#
#                             accuracy                           0.80      6959
#                            macro avg       0.77      0.77      0.77      6959
#                         weighted avg       0.80      0.80      0.80      6959
