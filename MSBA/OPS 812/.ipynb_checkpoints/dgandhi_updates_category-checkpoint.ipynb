# %% [markdown]
# https://towardsdatascience.com/multi-class-text-classification-model-comparison-and-selection-5eb066197568

# %%
import glob
import pandas as pd
import numpy as np
import json

# %%
annotations=glob.glob('data/OPP-115/annotations/*')

# %%
annotations_list=[]
for file in annotations:
    annotations_list.append(pd.read_csv(file, header=None))

# %%
annot=pd.concat(annotations_list, ignore_index=True)

# %%
annot.columns = ['annotation_ID', 'batch_ID', 'annotator_ID', 'policy_ID', 'segment_ID','category_name',
            'attribute_value_pairs','date','policy_URL']

# %%
annot['dict'] = annot.attribute_value_pairs.apply(lambda x: json.loads(x))

# %%
annot.head()
# Out:
#    annotation_ID                                       batch_ID  annotator_ID  \
# 0          13160  test_category_labeling_highlight_fordham_aaaa           121
# 1          13161  test_category_labeling_highlight_fordham_aaaa           121
# 2          13162  test_category_labeling_highlight_fordham_aaaa           121
# 3          13163  test_category_labeling_highlight_fordham_aaaa           121
# 4          13164  test_category_labeling_highlight_fordham_aaaa           121
#
#    policy_ID  segment_ID               category_name  \
# 0       3828           0                       Other
# 1       3828           1  First Party Collection/Use
# 2       3828           1  First Party Collection/Use
# 3       3828           1  First Party Collection/Use
# 4       3828           1  First Party Collection/Use
#
#                                attribute_value_pairs    date  \
# 0  {"Other Type": {"endIndexInSegment": 575, "sta...  5/7/15
# 1  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 2  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 3  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
# 4  {"Collection Mode": {"endIndexInSegment": -1, ...  5/7/15
#
#                                           policy_URL  \
# 0  http://www.kraftrecipes.com/about/privacynotic...
# 1  http://www.kraftrecipes.com/about/privacynotic...
# 2  http://www.kraftrecipes.com/about/privacynotic...
# 3  http://www.kraftrecipes.com/about/privacynotic...
# 4  http://www.kraftrecipes.com/about/privacynotic...
#
#                                                 dict
# 0  {'Other Type': {'endIndexInSegment': 575, 'sta...
# 1  {'Collection Mode': {'endIndexInSegment': -1, ...
# 2  {'Collection Mode': {'endIndexInSegment': -1, ...
# 3  {'Collection Mode': {'endIndexInSegment': -1, ...
# 4  {'Collection Mode': {'endIndexInSegment': -1, ...

# %%
for x in annot['dict']:
    for key, value in x.items():
        value.pop('endIndexInSegment', None)
        value.pop('startIndexInSegment', None)

# %%
text=[]
category=[]
subcat=[]
label=[]
counter=0
for i,x in enumerate(annot['dict']):
    for key, value in x.items():
        subcat.append(key)
        if value.get('selectedText')==None:
            text.append('noSelectedText')
        else:
            text.append(value.get('selectedText'))  
        category.append(annot['category_name'][i])
        for k, v in value.items():
            if k=='value':
                label.append(v)

# %%
d=list(zip(text, category, subcat, label))

# %%
data=pd.DataFrame(d, columns=['text', 'category', 'subcategory', 'label'])

# %%
data.head()
# Out:
#                                                 text  \
# 0  Effective Date: May 7, 2015 Kraft Site Privacy...
# 1                                     noSelectedText
# 2                                             collec
# 3  register on our website or participate in our ...
# 4       personally-identifiable information, such as
#
#                      category                subcategory  \
# 0                       Other                 Other Type
# 1  First Party Collection/Use            Collection Mode
# 2  First Party Collection/Use               Choice Scope
# 3  First Party Collection/Use         Action First-Party
# 4  First Party Collection/Use  Personal Information Type
#
#                           label
# 0          Introductory/Generic
# 1                  not-selected
# 2                    Collection
# 3            Collect on website
# 4  Generic personal information

# %%
data['cat_sub'] = data['category'] +'-'+ data['subcategory']

# %%
data.groupby('cat_sub').count()
# Out:
#                                                     text  category  \
# cat_sub
# Data Retention-Personal Information Type             370       370
# Data Retention-Retention Period                      370       370
# Data Retention-Retention Purpose                     370       370
# Data Security-Security Measure                      1008      1008
# Do Not Track-Do Not Track policy                      90        90
# First Party Collection/Use-Action First-Party       8935      8935
# First Party Collection/Use-Choice Scope             8935      8935
# First Party Collection/Use-Choice Type              8935      8935
# First Party Collection/Use-Collection Mode          8935      8935
# First Party Collection/Use-Does/Does Not            8935      8935
# First Party Collection/Use-Identifiability          8935      8935
# First Party Collection/Use-Personal Information...  8935      8935
# First Party Collection/Use-Purpose                  8935      8935
# First Party Collection/Use-User Type                8935      8935
# International and Specific Audiences-Audience Type   939       939
# Other-Other Type                                    3548      3548
# Policy Change-Change Type                            548       548
# Policy Change-Notification Type                      548       548
# Policy Change-User Choice                            548       548
# Third Party Sharing/Collection-Action Third Party   5221      5221
# Third Party Sharing/Collection-Choice Scope         5221      5221
# Third Party Sharing/Collection-Choice Type          5221      5221
# Third Party Sharing/Collection-Does/Does Not        5221      5221
# Third Party Sharing/Collection-Identifiability      5221      5221
# Third Party Sharing/Collection-Personal Informa...  5221      5221
# Third Party Sharing/Collection-Purpose              5221      5221
# Third Party Sharing/Collection-Third Party Entity   5221      5221
# Third Party Sharing/Collection-User Type            5221      5221
# User Access, Edit and Deletion-Access Scope          746       746
# User Access, Edit and Deletion-Access Type           746       746
# User Access, Edit and Deletion-User Type             746       746
# User Choice/Control-Choice Scope                    1789      1789
# User Choice/Control-Choice Type                     1789      1789
# User Choice/Control-Personal Information Type       1789      1789
# User Choice/Control-Purpose                         1789      1789
# User Choice/Control-User Type                       1789      1789
#
#                                                     subcategory  label
# cat_sub
# Data Retention-Personal Information Type                    370    370
# Data Retention-Retention Period                             370    370
# Data Retention-Retention Purpose                            370    370
# Data Security-Security Measure                             1008   1008
# Do Not Track-Do Not Track policy                             90     90
# First Party Collection/Use-Action First-Party              8935   8935
# First Party Collection/Use-Choice Scope                    8935   8935
# First Party Collection/Use-Choice Type                     8935   8935
# First Party Collection/Use-Collection Mode                 8935   8935
# First Party Collection/Use-Does/Does Not                   8935   8935
# First Party Collection/Use-Identifiability                 8935   8935
# First Party Collection/Use-Personal Information...         8935   8935
# First Party Collection/Use-Purpose                         8935   8935
# First Party Collection/Use-User Type                       8935   8935
# International and Specific Audiences-Audience Type          939    939
# Other-Other Type                                           3548   3548
# Policy Change-Change Type                                   548    548
# Policy Change-Notification Type                             548    548
# Policy Change-User Choice                                   548    548
# Third Party Sharing/Collection-Action Third Party          5221   5221
# Third Party Sharing/Collection-Choice Scope                5221   5221
# Third Party Sharing/Collection-Choice Type                 5221   5221
# Third Party Sharing/Collection-Does/Does Not               5221   5221
# Third Party Sharing/Collection-Identifiability             5221   5221
# Third Party Sharing/Collection-Personal Informa...         5221   5221
# Third Party Sharing/Collection-Purpose                     5221   5221
# Third Party Sharing/Collection-Third Party Entity          5221   5221
# Third Party Sharing/Collection-User Type                   5221   5221
# User Access, Edit and Deletion-Access Scope                 746    746
# User Access, Edit and Deletion-Access Type                  746    746
# User Access, Edit and Deletion-User Type                    746    746
# User Choice/Control-Choice Scope                           1789   1789
# User Choice/Control-Choice Type                            1789   1789
# User Choice/Control-Personal Information Type              1789   1789
# User Choice/Control-Purpose                                1789   1789
# User Choice/Control-User Type                              1789   1789

# %%
data.groupby(['category','subcategory']).nunique().count()
# Out:
# text           36
# category       36
# subcategory    36
# label          36
# cat_sub        36
# dtype: int64

# %%
data['cat_sub_lab'] = data['category'] +'-'+ data['subcategory'] +'-'+ data['label']

# %%
import string, re
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct
data['text'] = data['text'].apply(lambda x : remove_punct(x.lower()))

data = data[data['text']!='null']
data = data[data['text']!='noselectedtext']
data = data[data['text']!='']
data = data[data['text']!=' ']
data.reset_index(inplace=True, drop=True)
ds = data.drop_duplicates()

# %%
ds.shape
# Out:
# (36717, 6)

# %%
ds.groupby('category').count()
# Out:
#                                        text  subcategory  label  cat_sub  \
# category
# Data Retention                          676          676    676      676
# Data Security                           808          808    808      808
# Do Not Track                             67           67     67       67
# First Party Collection/Use            15346        15346  15346    15346
# International and Specific Audiences    582          582    582      582
# Other                                  2759         2759   2759     2759
# Policy Change                           932          932    932      932
# Third Party Sharing/Collection        10655        10655  10655    10655
# User Access, Edit and Deletion         1094         1094   1094     1094
# User Choice/Control                    3798         3798   3798     3798
#
#                                       cat_sub_lab
# category
# Data Retention                                676
# Data Security                                 808
# Do Not Track                                   67
# First Party Collection/Use                  15346
# International and Specific Audiences          582
# Other                                        2759
# Policy Change                                 932
# Third Party Sharing/Collection              10655
# User Access, Edit and Deletion               1094
# User Choice/Control                          3798

# %%
ds.groupby(['category','subcategory']).count().shape
# Out:
# (36, 4)

# %%
ds.groupby(['category','subcategory','label']).count().shape
# Out:
# (259, 3)

# %%
ds['tokenized'] = ds['text'].apply(lambda x : re.split(' ', x))
# ds['tokenized_text']=res
# Out:
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from gensim.models import Word2Vec
import logging
 
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
w2v = Word2Vec(ds['tokenized'])
# Out:
# 2019-09-15 14:03:26,135 : INFO : collecting all words and their counts
# 2019-09-15 14:03:26,140 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-09-15 14:03:26,204 : INFO : PROGRESS: at sentence #10000, processed 150297 words, keeping 3400 word types
# 2019-09-15 14:03:26,252 : INFO : PROGRESS: at sentence #20000, processed 311668 words, keeping 5095 word types
# 2019-09-15 14:03:26,304 : INFO : PROGRESS: at sentence #30000, processed 476465 words, keeping 6341 word types
# 2019-09-15 14:03:26,345 : INFO : collected 7149 word types from a corpus of 596891 raw words and 36717 sentences
# 2019-09-15 14:03:26,347 : INFO : Loading a fresh vocabulary
# 2019-09-15 14:03:26,370 : INFO : min_count=5 retains 3932 unique words (55% of original 7149, drops 3217)
# 2019-09-15 14:03:26,377 : INFO : min_count=5 leaves 589885 word corpus (98% of original 596891, drops 7006)
# 2019-09-15 14:03:26,433 : INFO : deleting the raw counts dictionary of 7149 items
# 2019-09-15 14:03:26,451 : INFO : sample=0.001 downsamples 58 most-common words
# 2019-09-15 14:03:26,460 : INFO : downsampling leaves estimated 405586 word corpus (68.8% of prior 589885)
# 2019-09-15 14:03:26,493 : INFO : estimated required memory for 3932 words and 100 dimensions: 5111600 bytes
# 2019-09-15 14:03:26,496 : INFO : resetting layer weights
# 2019-09-15 14:03:26,618 : INFO : training model with 3 workers on 3932 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-09-15 14:03:27,108 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-09-15 14:03:27,119 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-09-15 14:03:27,124 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-09-15 14:03:27,125 : INFO : EPOCH - 1 : training on 596891 raw words (405737 effective words) took 0.5s, 850187 effective words/s
# 2019-09-15 14:03:27,672 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-09-15 14:03:27,678 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-09-15 14:03:27,682 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-09-15 14:03:27,683 : INFO : EPOCH - 2 : training on 596891 raw words (405535 effective words) took 0.5s, 739185 effective words/s
# 2019-09-15 14:03:28,163 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-09-15 14:03:28,175 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-09-15 14:03:28,176 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-09-15 14:03:28,177 : INFO : EPOCH - 3 : training on 596891 raw words (405778 effective words) took 0.5s, 852535 effective words/s
# 2019-09-15 14:03:28,615 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-09-15 14:03:28,618 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-09-15 14:03:28,619 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-09-15 14:03:28,620 : INFO : EPOCH - 4 : training on 596891 raw words (405157 effective words) took 0.4s, 935985 effective words/s
# 2019-09-15 14:03:29,496 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-09-15 14:03:29,512 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-09-15 14:03:29,516 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-09-15 14:03:29,516 : INFO : EPOCH - 5 : training on 596891 raw words (405768 effective words) took 0.9s, 457721 effective words/s
# 2019-09-15 14:03:29,518 : INFO : training on a 2984455 raw words (2027975 effective words) took 2.9s, 701095 effective words/s

# %%
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder()

# %%
ds.reset_index(inplace=True, drop=True)

# %%
word_vectors = w2v.wv

# %%
word2id = {k: v.index for k, v in word_vectors.vocab.items()}

# %%
def add_new_word(new_word, new_vector, new_index, embedding_matrix, word2id):
    embedding_matrix = np.insert(embedding_matrix, [new_index], [new_vector], axis=0)
    
    word2id = {word: (index+1) if index >= new_index else index for word, index in word2id.items()}
    word2id[new_word] = new_index
    return embedding_matrix, word2id

UNK_INDEX = 0
UNK_TOKEN = 'UNK'

embedding_matrix = word_vectors.vectors
unk_vector = embedding_matrix.mean(0)
embedding_matrix, word2id = add_new_word(UNK_TOKEN, unk_vector, UNK_INDEX, embedding_matrix, word2id)

# %%
len(word2id)
# Out:
# 3933

# %%
embedding_matrix.shape
# Out:
# (3933, 100)

# %%
embedding_matrix[0].shape
# Out:
# (100,)

# %%
embedding_matrix = np.insert(embedding_matrix, len(embedding_matrix), [np.zeros((100,))], axis=0)

# %%
len(embedding_matrix)
# Out:
# 3934

# %%
embedding_matrix[3933].shape
# Out:
# (100,)

# %%
def get_int_data(token_text, word2id):
    x = []
    unk_count = 0
    for item in token_text:
        temp=[]
        x.append(temp)
        for word in item:
            if word in word2id:
                temp.append(word2id.get(word))
            else:
                temp.append(UNK_INDEX)
                unk_count += 1
    print('Data created. Percentage of unknown words: %.3f' % (unk_count))
    return np.array(x)

x=get_int_data(ds.tokenized, word2id)
x.shape
# Out:
# Data created. Percentage of unknown words: 7006.000
# (36717,)

# %%
ds['enumerated_text']=x
# Out:
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#ds['enumerated_text']=ds['enumerated_text'].apply(lambda x: np.array(x))

# %%
# Out:
# Using TensorFlow backend.

# %%
target = ds.category

# %%
ds['Do_Not_Track'] = ds['category'].apply(lambda x: 1 if x == 'Do Not Track' else 0)
ds['Other'] = ds['category'].apply(lambda x: 1 if x == 'Other' else 0)
ds['First_Party_Collection_Use'] = ds['category'].apply(lambda x: 1 if x == 'First Party Collection/Use' else 0)
ds['Third_Party_Sharing_Collection'] = ds['category'].apply(lambda x: 1 if x == 'Third Party Sharing/Collection' else 0)
ds['User_Choice_Control'] = ds['category'].apply(lambda x: 1 if x == 'User Choice/Control' else 0)
ds['International_and_Specific_Audiences'] = ds['category'].apply(lambda x: 1 if x == 'International and Specific Audiences' else 0)
ds['Data_Security'] = ds['category'].apply(lambda x: 1 if x == 'Data Security' else 0)
ds['Policy_Change'] = ds['category'].apply(lambda x: 1 if x == 'Policy Change' else 0)
ds['Data_Retention'] = ds['category'].apply(lambda x: 1 if x == 'Data Retention' else 0)
ds['User_Access_Edit_and_Deletion'] = ds['category'].apply(lambda x: 1 if x == 'User Access, Edit and Deletion' else 0)
# Out:
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /miniconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# sanity check
print(ds['Do_Not_Track'].sum())
print(ds['Other'].sum())
print(ds['First_Party_Collection_Use'].sum())
print(ds['Third_Party_Sharing_Collection'].sum())
print(ds['User_Choice_Control'].sum())
print(ds['International_and_Specific_Audiences'].sum())
print(ds['Data_Security'].sum())
print(ds['Policy_Change'].sum())
print(ds['Data_Retention'].sum())
print(ds['User_Access_Edit_and_Deletion'].sum())
ds.head()
# Out:
# 67
# 2759
# 15346
# 10655
# 3798
# 582
# 808
# 932
# 676
# 1094
#                                                 text  \
# 0  effective date may 7 2015 kraft site privacy n...
# 1                                             collec
# 2  register on our website or participate in our ...
# 3         personallyidentifiable information such as
# 4  if you choose to register on our website or pa...
#
#                      category                subcategory  \
# 0                       Other                 Other Type
# 1  First Party Collection/Use               Choice Scope
# 2  First Party Collection/Use         Action First-Party
# 3  First Party Collection/Use  Personal Information Type
# 4  First Party Collection/Use                Choice Type
#
#                           label  \
# 0          Introductory/Generic
# 1                    Collection
# 2            Collect on website
# 3  Generic personal information
# 4                        Opt-in
#
#                                              cat_sub  \
# 0                                   Other-Other Type
# 1            First Party Collection/Use-Choice Scope
# 2      First Party Collection/Use-Action First-Party
# 3  First Party Collection/Use-Personal Informatio...
# 4             First Party Collection/Use-Choice Type
#
#                                          cat_sub_lab  \
# 0              Other-Other Type-Introductory/Generic
# 1  First Party Collection/Use-Choice Scope-Collec...
# 2  First Party Collection/Use-Action First-Party-...
# 3  First Party Collection/Use-Personal Informatio...
# 4      First Party Collection/Use-Choice Type-Opt-in
#
#                                            tokenized  \
# 0  [effective, date, may, 7, 2015, kraft, site, p...
# 1                                           [collec]
# 2  [register, on, our, website, or, participate, ...
# 3    [personallyidentifiable, information, such, as]
# 4  [if, you, choose, to, register, on, our, websi...
#
#                                      enumerated_text  Do_Not_Track  Other  \
# 0  [553, 244, 11, 2150, 839, 1332, 35, 26, 139, 2...             0      1
# 1                                             [2151]             0      0
# 2     [204, 19, 10, 52, 6, 212, 13, 10, 168, 3, 363]             0      0
# 3                                   [630, 5, 31, 23]             0      0
# 4  [32, 4, 105, 1, 204, 19, 10, 52, 6, 212, 13, 1...             0      0
#
#    First_Party_Collection_Use  Third_Party_Sharing_Collection  \
# 0                           0                               0
# 1                           1                               0
# 2                           1                               0
# 3                           1                               0
# 4                           1                               0
#
#    User_Choice_Control  International_and_Specific_Audiences  Data_Security  \
# 0                    0                                     0              0
# 1                    0                                     0              0
# 2                    0                                     0              0
# 3                    0                                     0              0
# 4                    0                                     0              0
#
#    Policy_Change  Data_Retention  User_Access_Edit_and_Deletion
# 0              0               0                              0
# 1              0               0                              0
# 2              0               0                              0
# 3              0               0                              0
# 4              0               0                              0

# %%
category_df = ds[['enumerated_text','Do_Not_Track','Other','First_Party_Collection_Use','Third_Party_Sharing_Collection',\
                  'User_Choice_Control','International_and_Specific_Audiences','Data_Security','Policy_Change','Data_Retention',\
                 'User_Access_Edit_and_Deletion']]
category_df.head()
# Out:
#                                      enumerated_text  Do_Not_Track  Other  \
# 0  [553, 244, 11, 2150, 839, 1332, 35, 26, 139, 2...             0      1
# 1                                             [2151]             0      0
# 2     [204, 19, 10, 52, 6, 212, 13, 10, 168, 3, 363]             0      0
# 3                                   [630, 5, 31, 23]             0      0
# 4  [32, 4, 105, 1, 204, 19, 10, 52, 6, 212, 13, 1...             0      0
#
#    First_Party_Collection_Use  Third_Party_Sharing_Collection  \
# 0                           0                               0
# 1                           1                               0
# 2                           1                               0
# 3                           1                               0
# 4                           1                               0
#
#    User_Choice_Control  International_and_Specific_Audiences  Data_Security  \
# 0                    0                                     0              0
# 1                    0                                     0              0
# 2                    0                                     0              0
# 3                    0                                     0              0
# 4                    0                                     0              0
#
#    Policy_Change  Data_Retention  User_Access_Edit_and_Deletion
# 0              0               0                              0
# 1              0               0                              0
# 2              0               0                              0
# 3              0               0                              0
# 4              0               0                              0

# %%
from keras.preprocessing.sequence import pad_sequences
max_length = max(category_df.enumerated_text.apply(lambda x: len(x)))
padded_docs = pad_sequences(category_df.enumerated_text, maxlen=max_length, padding='post', value=(len(embedding_matrix)-1))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Do_Not_Track, test_size=0.3, random_state = 0)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Embedding, Activation, Flatten

# %%
y_train.shape
# Out:
# (25701,)

# %%
len(y_train)
# Out:
# 25701

# %%
vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 300.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=5, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/5
# 25701/25701 [==============================] - 16s 631us/step - loss: 0.6786 - acc: 0.9508 - val_loss: 0.0481 - val_acc: 0.9894
# Epoch 2/5
# 25701/25701 [==============================] - 16s 624us/step - loss: 0.0335 - acc: 0.9954 - val_loss: 0.0529 - val_acc: 0.9834
# Epoch 3/5
# 25701/25701 [==============================] - 16s 638us/step - loss: 0.0106 - acc: 0.9975 - val_loss: 0.0064 - val_acc: 0.9988
# Epoch 4/5
# 25701/25701 [==============================] - 16s 640us/step - loss: 0.0095 - acc: 0.9983 - val_loss: 0.0166 - val_acc: 0.9952
# Epoch 5/5
# 25701/25701 [==============================] - 17s 650us/step - loss: 0.0027 - acc: 0.9994 - val_loss: 0.0053 - val_acc: 0.9991

# %%
from sklearn.metrics import confusion_matrix, f1_score
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# [[10990     7]
#  [    3    16]]
# 0.761904761904762

# %%
# Other Model
x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Other, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 15.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 18s 683us/step - loss: 0.8630 - acc: 0.7743 - val_loss: 0.4348 - val_acc: 0.8022
# Epoch 2/10
# 25701/25701 [==============================] - 16s 631us/step - loss: 0.5788 - acc: 0.8569 - val_loss: 0.4240 - val_acc: 0.8270
# Epoch 3/10
# 25701/25701 [==============================] - 16s 639us/step - loss: 0.3986 - acc: 0.9081 - val_loss: 0.3141 - val_acc: 0.8878
# Epoch 4/10
# 25701/25701 [==============================] - 17s 648us/step - loss: 0.2987 - acc: 0.9395 - val_loss: 0.2844 - val_acc: 0.9067
# Epoch 5/10
# 25701/25701 [==============================] - 17s 659us/step - loss: 0.2224 - acc: 0.9590 - val_loss: 0.3298 - val_acc: 0.9021
# Epoch 6/10
# 25701/25701 [==============================] - 17s 656us/step - loss: 0.1744 - acc: 0.9699 - val_loss: 0.3091 - val_acc: 0.9178
# Epoch 7/10
# 25701/25701 [==============================] - 18s 681us/step - loss: 0.1554 - acc: 0.9749 - val_loss: 0.3040 - val_acc: 0.9230
# Epoch 8/10
# 25701/25701 [==============================] - 18s 690us/step - loss: 0.1457 - acc: 0.9770 - val_loss: 0.3350 - val_acc: 0.9274
# Epoch 9/10
# 25701/25701 [==============================] - 18s 687us/step - loss: 0.1423 - acc: 0.9791 - val_loss: 0.3227 - val_acc: 0.9245
# Epoch 10/10
# 25701/25701 [==============================] - 18s 702us/step - loss: 0.1392 - acc: 0.9805 - val_loss: 0.3848 - val_acc: 0.9185

# %%
print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# [[9581  636]
#  [ 262  537]]
# 0.5446247464503042

# %%
#  First Party Collection/Use Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.First_Party_Collection_Use, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 15.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 17s 656us/step - loss: 1.7619 - acc: 0.4722 - val_loss: 1.3100 - val_acc: 0.4772
# Epoch 2/10
# 25701/25701 [==============================] - 17s 644us/step - loss: 1.4743 - acc: 0.5370 - val_loss: 0.8871 - val_acc: 0.5507
# Epoch 3/10
# 25701/25701 [==============================] - 17s 656us/step - loss: 1.3092 - acc: 0.5922 - val_loss: 0.8948 - val_acc: 0.6011
# Epoch 4/10
# 25701/25701 [==============================] - 17s 658us/step - loss: 1.1611 - acc: 0.6501 - val_loss: 1.0124 - val_acc: 0.6184
# Epoch 5/10
# 25701/25701 [==============================] - 18s 681us/step - loss: 1.0257 - acc: 0.6981 - val_loss: 0.9205 - val_acc: 0.6537
# Epoch 6/10
# 25701/25701 [==============================] - 18s 683us/step - loss: 0.9251 - acc: 0.7342 - val_loss: 0.9540 - val_acc: 0.6742
# Epoch 7/10
# 25701/25701 [==============================] - 18s 712us/step - loss: 0.8454 - acc: 0.7646 - val_loss: 1.0232 - val_acc: 0.6790
# Epoch 8/10
# 25701/25701 [==============================] - 19s 720us/step - loss: 0.8405 - acc: 0.7758 - val_loss: 0.9222 - val_acc: 0.7034
# Epoch 9/10
# 25701/25701 [==============================] - 19s 729us/step - loss: 0.7371 - acc: 0.8031 - val_loss: 0.8372 - val_acc: 0.7203
# Epoch 10/10
# 25701/25701 [==============================] - 19s 743us/step - loss: 0.6782 - acc: 0.8239 - val_loss: 0.9940 - val_acc: 0.7103
# [[3629 2765]
#  [ 426 4196]]
# 0.7245100578433912

# %%
#  Data Retention Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Data_Retention, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 3.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
#model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 19s 738us/step - loss: 0.2189 - acc: 0.9776 - val_loss: 0.0913 - val_acc: 0.9825
# Epoch 2/10
# 25701/25701 [==============================] - 17s 678us/step - loss: 0.1556 - acc: 0.9812 - val_loss: 0.1036 - val_acc: 0.9825
# Epoch 3/10
# 25701/25701 [==============================] - 18s 686us/step - loss: 0.1300 - acc: 0.9832 - val_loss: 0.0824 - val_acc: 0.9827
# Epoch 4/10
# 25701/25701 [==============================] - 17s 678us/step - loss: 0.1059 - acc: 0.9855 - val_loss: 0.0842 - val_acc: 0.9818
# Epoch 5/10
# 25701/25701 [==============================] - 17s 672us/step - loss: 0.0841 - acc: 0.9855 - val_loss: 0.0826 - val_acc: 0.9794
# Epoch 6/10
# 25701/25701 [==============================] - 17s 665us/step - loss: 0.0654 - acc: 0.9884 - val_loss: 0.0856 - val_acc: 0.9801
# Epoch 7/10
# 25701/25701 [==============================] - 19s 733us/step - loss: 0.0550 - acc: 0.9898 - val_loss: 0.0967 - val_acc: 0.9757
# Epoch 8/10
# 25701/25701 [==============================] - 19s 722us/step - loss: 0.0473 - acc: 0.9905 - val_loss: 0.1051 - val_acc: 0.9743
# Epoch 9/10
# 25701/25701 [==============================] - 19s 724us/step - loss: 0.0412 - acc: 0.9912 - val_loss: 0.1082 - val_acc: 0.9749
# Epoch 10/10
# 25701/25701 [==============================] - 18s 717us/step - loss: 0.0379 - acc: 0.9913 - val_loss: 0.1087 - val_acc: 0.9749
# [[10668   156]
#  [  121    71]]
# 0.33890214797136037

# %%
#  Data Security Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Data_Security, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 100.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
#model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 18s 686us/step - loss: 1.3001 - acc: 0.7189 - val_loss: 0.5573 - val_acc: 0.7845
# Epoch 2/10
# 25701/25701 [==============================] - 16s 630us/step - loss: 0.6138 - acc: 0.8714 - val_loss: 0.4139 - val_acc: 0.8607
# Epoch 3/10
# 25701/25701 [==============================] - 16s 639us/step - loss: 0.3189 - acc: 0.9360 - val_loss: 0.1775 - val_acc: 0.9444
# Epoch 4/10
# 25701/25701 [==============================] - 17s 673us/step - loss: 0.1942 - acc: 0.9638 - val_loss: 0.1778 - val_acc: 0.9453
# Epoch 5/10
# 25701/25701 [==============================] - 17s 669us/step - loss: 0.1272 - acc: 0.9770 - val_loss: 0.1754 - val_acc: 0.9470
# Epoch 6/10
# 25701/25701 [==============================] - 17s 672us/step - loss: 0.0885 - acc: 0.9847 - val_loss: 0.1359 - val_acc: 0.9645
# Epoch 7/10
# 25701/25701 [==============================] - 17s 658us/step - loss: 0.1005 - acc: 0.9815 - val_loss: 0.1155 - val_acc: 0.9715
# Epoch 8/10
# 25701/25701 [==============================] - 17s 657us/step - loss: 0.0647 - acc: 0.9889 - val_loss: 0.1169 - val_acc: 0.9757
# Epoch 9/10
# 25701/25701 [==============================] - 18s 690us/step - loss: 0.0579 - acc: 0.9935 - val_loss: 0.1400 - val_acc: 0.9690
# Epoch 10/10
# 25701/25701 [==============================] - 18s 707us/step - loss: 0.0589 - acc: 0.9916 - val_loss: 0.1257 - val_acc: 0.9778
# [[10602   157]
#  [   88   169]]
# 0.5797598627787307

# %%
#  International and Specific Audiences Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.International_and_Specific_Audiences, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 60.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
#model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 18s 685us/step - loss: 0.6034 - acc: 0.8862 - val_loss: 0.1447 - val_acc: 0.9521
# Epoch 2/10
# 25701/25701 [==============================] - 17s 647us/step - loss: 0.2528 - acc: 0.9565 - val_loss: 0.1621 - val_acc: 0.9512
# Epoch 3/10
# 25701/25701 [==============================] - 17s 649us/step - loss: 0.1208 - acc: 0.9796 - val_loss: 0.0870 - val_acc: 0.9815
# Epoch 4/10
# 25701/25701 [==============================] - 17s 664us/step - loss: 0.1023 - acc: 0.9841 - val_loss: 0.0890 - val_acc: 0.9799
# Epoch 5/10
# 25701/25701 [==============================] - 18s 686us/step - loss: 0.0774 - acc: 0.9886 - val_loss: 0.0869 - val_acc: 0.9819
# Epoch 6/10
# 25701/25701 [==============================] - 17s 674us/step - loss: 0.0591 - acc: 0.9925 - val_loss: 0.0917 - val_acc: 0.9819
# Epoch 7/10
# 25701/25701 [==============================] - 17s 680us/step - loss: 0.0409 - acc: 0.9951 - val_loss: 0.0774 - val_acc: 0.9869
# Epoch 8/10
# 25701/25701 [==============================] - 17s 680us/step - loss: 0.0323 - acc: 0.9963 - val_loss: 0.0762 - val_acc: 0.9875
# Epoch 9/10
# 25701/25701 [==============================] - 18s 691us/step - loss: 0.0282 - acc: 0.9967 - val_loss: 0.0745 - val_acc: 0.9885
# Epoch 10/10
# 25701/25701 [==============================] - 18s 706us/step - loss: 0.0260 - acc: 0.9971 - val_loss: 0.0780 - val_acc: 0.9879
# [[10753    76]
#  [   57   130]]
# 0.6615776081424937

# %%
#  Policy Change Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Policy_Change, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 40.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
#model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 20s 779us/step - loss: 0.5926 - acc: 0.8963 - val_loss: 0.1894 - val_acc: 0.9350
# Epoch 2/10
# 25701/25701 [==============================] - 18s 691us/step - loss: 0.2595 - acc: 0.9546 - val_loss: 0.1711 - val_acc: 0.9402
# Epoch 3/10
# 25701/25701 [==============================] - 17s 680us/step - loss: 0.1589 - acc: 0.9693 - val_loss: 0.1107 - val_acc: 0.9624
# Epoch 4/10
# 25701/25701 [==============================] - 17s 676us/step - loss: 0.0966 - acc: 0.9811 - val_loss: 0.0679 - val_acc: 0.9787
# Epoch 5/10
# 25701/25701 [==============================] - 17s 675us/step - loss: 0.0751 - acc: 0.9855 - val_loss: 0.0814 - val_acc: 0.9762
# Epoch 6/10
# 25701/25701 [==============================] - 17s 675us/step - loss: 0.0591 - acc: 0.9894 - val_loss: 0.0791 - val_acc: 0.9769
# Epoch 7/10
# 25701/25701 [==============================] - 18s 713us/step - loss: 0.0537 - acc: 0.9904 - val_loss: 0.0757 - val_acc: 0.9779
# Epoch 8/10
# 25701/25701 [==============================] - 19s 730us/step - loss: 0.0441 - acc: 0.9921 - val_loss: 0.0659 - val_acc: 0.9841
# Epoch 9/10
# 25701/25701 [==============================] - 18s 719us/step - loss: 0.0497 - acc: 0.9919 - val_loss: 0.0881 - val_acc: 0.9805
# Epoch 10/10
# 25701/25701 [==============================] - 18s 708us/step - loss: 0.0701 - acc: 0.9879 - val_loss: 0.0917 - val_acc: 0.9780
# [[10549   183]
#  [   59   225]]
# 0.6502890173410404

# %%
#  Third Party Sharing/Collection Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.Third_Party_Sharing_Collection, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 3.5}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
#model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 18s 692us/step - loss: 0.9709 - acc: 0.6284 - val_loss: 0.5724 - val_acc: 0.7012
# Epoch 2/10
# 25701/25701 [==============================] - 17s 649us/step - loss: 0.7973 - acc: 0.7200 - val_loss: 0.5535 - val_acc: 0.7135
# Epoch 3/10
# 25701/25701 [==============================] - 17s 655us/step - loss: 0.6757 - acc: 0.7737 - val_loss: 0.5161 - val_acc: 0.7429
# Epoch 4/10
# 25701/25701 [==============================] - 17s 661us/step - loss: 0.5846 - acc: 0.8135 - val_loss: 0.5562 - val_acc: 0.7364
# Epoch 5/10
# 25701/25701 [==============================] - 19s 746us/step - loss: 0.5122 - acc: 0.8404 - val_loss: 0.6011 - val_acc: 0.7207
# Epoch 6/10
# 25701/25701 [==============================] - 16s 633us/step - loss: 0.4566 - acc: 0.8600 - val_loss: 0.5923 - val_acc: 0.7505
# Epoch 7/10
# 25701/25701 [==============================] - 14s 556us/step - loss: 0.4206 - acc: 0.8725 - val_loss: 0.6351 - val_acc: 0.7542
# Epoch 8/10
# 25701/25701 [==============================] - 15s 601us/step - loss: 0.3992 - acc: 0.8811 - val_loss: 0.6264 - val_acc: 0.7589
# Epoch 9/10
# 25701/25701 [==============================] - 17s 645us/step - loss: 0.3618 - acc: 0.8942 - val_loss: 0.6196 - val_acc: 0.7714
# Epoch 10/10
# 25701/25701 [==============================] - 18s 682us/step - loss: 0.3611 - acc: 0.8970 - val_loss: 0.6684 - val_acc: 0.7530
# [[5961 1863]
#  [ 858 2334]]
# 0.631749898497767

# %%
#  User Access, Edit and Deletion Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.User_Access_Edit_and_Deletion, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 3.5}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
#model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 20s 775us/step - loss: 0.2576 - acc: 0.9681 - val_loss: 0.1076 - val_acc: 0.9690
# Epoch 2/10
# 25701/25701 [==============================] - 17s 679us/step - loss: 0.1650 - acc: 0.9725 - val_loss: 0.1031 - val_acc: 0.9689
# Epoch 3/10
# 25701/25701 [==============================] - 17s 668us/step - loss: 0.1212 - acc: 0.9785 - val_loss: 0.0997 - val_acc: 0.9705
# Epoch 4/10
# 25701/25701 [==============================] - 17s 665us/step - loss: 0.0952 - acc: 0.9825 - val_loss: 0.0928 - val_acc: 0.9704
# Epoch 5/10
# 25701/25701 [==============================] - 17s 662us/step - loss: 0.0762 - acc: 0.9851 - val_loss: 0.0989 - val_acc: 0.9704
# Epoch 6/10
# 25701/25701 [==============================] - 17s 661us/step - loss: 0.0636 - acc: 0.9870 - val_loss: 0.1065 - val_acc: 0.9679
# Epoch 7/10
# 25701/25701 [==============================] - 18s 697us/step - loss: 0.0554 - acc: 0.9886 - val_loss: 0.1094 - val_acc: 0.9674
# Epoch 8/10
# 25701/25701 [==============================] - 18s 709us/step - loss: 0.0518 - acc: 0.9892 - val_loss: 0.1157 - val_acc: 0.9688
# Epoch 9/10
# 25701/25701 [==============================] - 19s 721us/step - loss: 0.0452 - acc: 0.9904 - val_loss: 0.1258 - val_acc: 0.9656
# Epoch 10/10
# 25701/25701 [==============================] - 18s 699us/step - loss: 0.0435 - acc: 0.9905 - val_loss: 0.1235 - val_acc: 0.9688
# [[10491   168]
#  [  176   181]]
# 0.5127478753541075

# %%
#  User Choice/Control Model

x_train, x_test, y_train, y_test = train_test_split(padded_docs, category_df.User_Choice_Control, test_size=0.3, random_state = 0)

vocab_length = len(embedding_matrix)

class_weights = {0: 1.,
                1: 75.}

model = Sequential()
model.add(Embedding(input_dim=vocab_length,
                   output_dim=100,
                   weights=[embedding_matrix],
                   input_length=padded_docs.shape[1]))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=10, batch_size=100,\
                  validation_data=(x_test, y_test),class_weight=class_weights)

print(confusion_matrix(y_test,model.predict_classes(x_test)))
print(f1_score(y_test, model.predict_classes(x_test)))
# Out:
# Train on 25701 samples, validate on 11016 samples
# Epoch 1/10
# 25701/25701 [==============================] - 18s 709us/step - loss: 2.4977 - acc: 0.1613 - val_loss: 1.4181 - val_acc: 0.2240
# Epoch 2/10
# 25701/25701 [==============================] - 17s 661us/step - loss: 1.9997 - acc: 0.3525 - val_loss: 1.1973 - val_acc: 0.3416
# Epoch 3/10
# 25701/25701 [==============================] - 17s 664us/step - loss: 1.6448 - acc: 0.4936 - val_loss: 1.0864 - val_acc: 0.5237
# Epoch 4/10
# 25701/25701 [==============================] - 17s 655us/step - loss: 1.4173 - acc: 0.5838 - val_loss: 0.8894 - val_acc: 0.6247
# Epoch 5/10
# 25701/25701 [==============================] - 17s 673us/step - loss: 1.1809 - acc: 0.6792 - val_loss: 0.7076 - val_acc: 0.7094
# Epoch 6/10
# 25701/25701 [==============================] - 17s 666us/step - loss: 0.9766 - acc: 0.7399 - val_loss: 0.6725 - val_acc: 0.7441
# Epoch 7/10
# 25701/25701 [==============================] - 18s 683us/step - loss: 0.8752 - acc: 0.7720 - val_loss: 0.7532 - val_acc: 0.7302
# Epoch 8/10
# 25701/25701 [==============================] - 18s 688us/step - loss: 0.8015 - acc: 0.7934 - val_loss: 0.6616 - val_acc: 0.7745
# Epoch 9/10
# 25701/25701 [==============================] - 18s 696us/step - loss: 0.7317 - acc: 0.8175 - val_loss: 0.7883 - val_acc: 0.7464
# Epoch 10/10
# 25701/25701 [==============================] - 18s 700us/step - loss: 0.7092 - acc: 0.8240 - val_loss: 0.8677 - val_acc: 0.7236
# [[7070 2839]
#  [ 206  901]]
# 0.3717763565091809
